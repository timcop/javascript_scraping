# %%
from bs4 import BeautifulSoup
import requests

# %%
ads_all = []
base_url = "https://www.bidbud.co.nz/search?category=0002-0356-0032-2273-&page="

page_num = 1

response = requests.get("https://www.bidbud.co.nz/search?category=0002-0356-0032-2273-&page=" + str(page_num))
html = response.content
soup = BeautifulSoup(html, "html.parser")
page_ads = soup.find_all('a', class_="listing_title")

ads_all.extend(page_ads)

while len(page_ads) > 0:
    page_num += 1
    response = requests.get("https://www.bidbud.co.nz/search?category=0002-0356-0032-2273-&page=" + str(page_num))
    html = response.content
    soup = BeautifulSoup(html, "html.parser")
    page_ads = soup.find_all('a', class_="listing_title")

    ads_all.extend(page_ads)

ads_hrefs = [a.get('href') for a in ads_all]

# %%
listing_base_url = "https://www.bidbud.co.nz/"

response = requests.get("https://www.bidbud.co.nz/" + ads_hrefs[0])
# Out:
# (b'<!DOCTYPE html>\r\n<html lang="en" itemscope itemtype="http://schema.org/W'
#  b'ebPage">\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <meta itemprop="'
#  b'name" content="Apple Macbook Pro 2017 15.4&quot; Touchbar 16GB Mem / 512GB S'
#  b'toreage : BidBud">\r\n    <meta property="og:title" content="Apple Macbook'
#  b' Pro 2017 15.4&quot; Touchbar 16GB Mem / 512GB Storeage">\r\n    <meta pro'
#  b'perty="og:url" content="https://www.bidbud.co.nz/4754794981">\r\n    <meta'
#  b' property="og:site_name" content="BidBud">\r\n    <meta property="fb:admin'
#  b's" content="722710373">\r\n        <meta property="og:type" content="produ'
#  b'ct">\r\n            <meta property="og:description" content="MacBook Pro 1'
#  b'5 2017 - Core i7 2.9GHz 16GB RAM 512GB SSD. Space Grey. One owner. Ex Agency'
#  b'. Very Good Condition. Very few marks or scratched - always kept in 2 cases '
#  b'when travelling a soft case &amp; a study 2nd case. Screen size 15.">\r\n '
#  b'           <meta property="og:image" content="https://trademe.tmcdn.co.nz/ph'
#  b'otoserver/full/2123381177.jpg">\r\n                \r\n    <meta name="viewp'
#  b'ort" content="width=device-width, initial-scale=1.0, user-scalable=yes">'
#  b'\r\n    \r\n    <title>Apple Macbook Pro 2017 15.4&quot; Touchbar 16GB Mem /'
#  b' 512GB Storeage : BidBud</title>\r\n    <meta http-equiv="X-UA-Compatible"'
#  b' content="IE=Edge">\r\n\t<link rel="stylesheet" type="text/css" href="https'
#  b'://www.bidbud.co.nz/assets/css/royalslider/royalslider.css?v=170" media="scr'
#  b'een">\n<link rel="stylesheet" type="text/css" href="https://www.bidbud.co'
#  b'.nz/assets/css/royalslider/skins/default-inverted/rs-default-inverted.css?v='
#  b'170" media="screen">\n<link rel="stylesheet" type="text/css" href="https:'
#  b'//www.bidbud.co.nz/bonfire/themes/bootstrap3/css/bootstrap.css?v=170" media='
#  b'"all">\n    <link rel="stylesheet" type="text/css" href="/bonfire/themes/'
#  b'default/print.css" media="print" />\r\n    <link rel="search" type="applic'
#  b'ation/opensearchdescription+xml" title="BidBud" href="/opensearch.xml" /'
#  b'>\r\n    \r\n    <link rel="apple-touch-icon" sizes="144x144" href="/apple-t'
#  b'ouch-icon.png">\r\n    <link rel="icon" type="image/png" href="/favicon-32'
#  b'x32.png" sizes="32x32">\r\n    <link rel="icon" type="image/png" href="/fa'
#  b'vicon-16x16.png" sizes="16x16">\r\n    <link rel="manifest" href="/manifes'
#  b't.json">\r\n    <link rel="mask-icon" href="/safari-pinned-tab.svg" color='
#  b'"#5bbad5">\r\n    <meta name="apple-mobile-web-app-title" content="BidBud"'
#  b'>\r\n    <meta name="application-name" content="BidBud">\r\n    <meta name="'
#  b'theme-color" content="#ffffff">\r\n<script>\r\n  (function(i,s,o,g,r,a,m){i['
#  b"'GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(ar"
#  b'guments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName('
#  b"o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'sc"
#  b"ript','https://www.google-analytics.com/analytics.js','ga');\r\n  ga('crea"
#  b"te', 'UA-36760526-1', 'auto');\r\n    ga('send', 'pageview');\r\n  var csrf_"
#  b"token = 'e86778684560ad4e86d7bb0d273736e7';\r\n  \r\n</script>\r\n<script "
#  b'src="/assets/js/ads.js"></script>\r\n  </head>\r\n<body><div id="navbar" cla'
#  b'ss="navbar-default navbar-ontop" role="navigation">\r\n    <div class="con'
#  b'tainer">\r\n      <div class="navbar-header">\r\n            \r\n         '
#  b'   <button type="button" class="navbar-toggle" data-toggle="collapse" data-t'
#  b'arget=".navbar-collapse">\r\n\t\t\t\t<span class="icon-bar"></span>\r\n\t'
#  b'\t\t\t<span class="icon-bar"></span>\r\n\t\t\t\t<span class="icon-bar"></'
#  b'span>\r\n\t\t\t</button>\r\n\t\t\t<a href="/" class="pull-left" style="mar'
#  b'gin: 3px 5px 0 3px;"><img src="/images/header_logo.png" height="34" width="1'
#  b'11"></a>\r\n            <form action="/search" class="mobile-search hidden'
#  b'-sm hidden-md hidden-lg pull-right" method="get">\r\n              \r\n     '
#  b'       <input type="text" name="search_string" class="form-control" value=""'
#  b' placeholder="Quick search">\r\n            </form>\r\n      </div>\r\n   '
#  b'   <div class="navbar-collapse collapse">\r\n      <ul class="nav navbar-n'
#  b'av" role="navigation">\r\n        \r\n        <li class="dropdown hidden-xs"'
#  b'>\r\n          <a id="browse" href="#" role="button" class="dropdown-toggl'
#  b'e" data-toggle="dropdown">Browse<b class="caret"></b></a>\r\n          <di'
#  b'v class="dropdown-menu" role="menu">\r\n          <div class="multi-column'
#  b'-large row">\r\n                    <ul class="col-sm-4">\r\n               '
#  b'         <li><a href="/browse/Antiques-collectables">Antiques &amp; Collecta'
#  b'bles</a></li>\r\n                        <li><a href="/browse/Art">Art</a>'
#  b'</li>\r\n                        <li><a href="/browse/Baby-gear">Baby Gear'
#  b'</a></li>\r\n                        <li><a href="/browse/Books">Books</a>'
#  b'</li>\r\n                        <li><a href="/browse/Building-renovation"'
#  b'>Building &amp; Renovation</a></li>\r\n                        <li><a href'
#  b'="/browse/Business-farming-industry">Business &amp; Industry</a></li>\r\n '
#  b'                       <li><a href="/browse/Clothing-fashion">Clothing &amp;'
#  b' Fashion</a></li>\r\n                        <li><a href="/browse/Computer'
#  b's">Computers</a></li>\r\n                        <li><a href="/browse/Craf'
#  b'ts">Crafts</a></li>\r\n                        <li><a href="/browse/Electr'
#  b'onics-photography">Electronics &amp; Photography</a></li>\r\n             '
#  b'           <li><a href="/browse/Flatmates-wanted">Flatmates Wanted</a></'
#  b'li>\r\n                    </ul>\r\n                    <ul class="col-sm-4"'
#  b'>\r\n                        <li><a href="/browse/Gaming">Gaming</a></li>\r'
#  b'\n                        <li><a href="/browse/Health-beauty">Health &amp'
#  b'; Beauty</a></li>\r\n                        <li><a href="/browse/Home-liv'
#  b'ing">Home &amp; Living</a></li>\r\n                        <li><a href="/b'
#  b'rowse/Jewellery-watches">Jewellery &amp; Watches</a></li>\r\n             '
#  b'           <li><a href="/browse/Jobs">Jobs</a></li>\r\n                   '
#  b'     <li><a href="/browse/Mobile-phones">Mobile Phones</a></li>\r\n       '
#  b'                 <li><a href="/browse/Motors">Motors</a></li>\r\n         '
#  b'               <li><a href="/browse/Movies-TV">Movies &amp; TV</a></li>\r'
#  b'\n                        <li><a href="/browse/Music-instruments">Music &'
#  b'amp; Instruments</a></li>\r\n                        <li><a href="/browse/'
#  b'Pets-animals">Pets &amp; Animals</a></li>\r\n                        <li><'
#  b'a href="/browse/Pottery-glass">Pottery &amp; Glass</a></li>\r\n           '
#  b'         </ul>\r\n                    <ul class="col-sm-4">\r\n             '
#  b'           \r\n                        <li><a href="/browse/Property">Real'
#  b' Estate</a></li>\r\n                        <li><a href="/browse/Services"'
#  b'>Services</a></li>\r\n                        <li><a href="/browse/Sports"'
#  b'>Sports</a></li>\r\n                        <li><a href="/browse/Toys-mode'
#  b'ls">Toys &amp; Models</a></li>\r\n                        <li><a href="/br'
#  b'owse/Travel-events-activities">Travel, Events &amp; Activities</a></li>\r'
#  b'\n                        <li><a>&nbsp;</a></li>\r\n                       '
#  b' <li><a href="/browse">Full category list</a></li>\r\n                    '
#  b'    <li><a href="/browse/dollar_reserve">$1 Reserve</a></li>\r\n          '
#  b'              <li><a href="/browse/hot">Hot Listings</a></li>\r\n         '
#  b'               <li><a href="/browse/latest">Latest Listings</a></li>\r\n  '
#  b'                      <li><a href="/browse/closing">Closing Soon</a></li'
#  b'>\r\n                    </ul>\r\n            </div>\r\n            </div>'
#  b'\r\n        </li>\r\n        \r\n        <li class="dropdown visible-xs">\r'
#  b'\n          <a id="browse" href="#" role="button" class="dropdown-toggle"'
#  b' data-toggle="dropdown">Browse<b class="caret"></b></a>\r\n          <ul c'
#  b'lass="dropdown-menu" role="menu"> \r\n            <li><a href="/browse">Fu'
#  b'll category list</a></li>\r\n            <li><a href="/browse/dollar_reser'
#  b've">$1 reserve</a></li>\r\n            <li><a href="/browse/hot">Hot listi'
#  b'ngs</a></li>\r\n            <li><a href="/browse/latest">Latest listings</'
#  b'a></li>\r\n            <li><a href="/browse/closing">Closing soon</a></li>'
#  b'\r\n          </ul>  \r\n          </li>\r\n        \r\n        \r\n      '
#  b'          <li><a href="/sell">Sell</a></li>\r\n                <li><a href'
#  b'="/search">Search</a></li>\r\n                        <li><a href="/feedba'
#  b'ck">Feedback</a></li>\r\n        \r\n        <li class="dropdown">\r\n    '
#  b'      <a id="help" href="#" role="button" class="dropdown-toggle" data-toggl'
#  b'e="dropdown">Help<b class="caret"></b></a>\r\n          <ul class="dropdow'
#  b'n-menu" role="menu">\r\n            <li><a href="/faq">Frequently Asked Qu'
#  b'estions</a></li>\r\n            <li><a href="/about">About</a></li>\r\n     '
#  b'       <li><a href="https://stats.uptimerobot.com/798PEUQKj" rel="noopener">'
#  b'Server status</a></li>\r\n            <li><a href="/contact">Contact</a></'
#  b'li>\r\n          </ul>\r\n        </li>\r\n      <li class="small-search">'
#  b'\r\n      <form action="/search" class="navbar-form hidden-xs" method="get'
#  b'">\r\n      <div class="form-group">\r\n      <input id="quick_search" type='
#  b'"text" name="search_string" class="form-control" placeholder="Quick search">'
#  b'\r\n      </div>\r\n      </form>\r\n      </li>\r\n      </ul>\r\n      <'
#  b'ul class="nav navbar-nav navbar-right">\r\n                <li class="hide'
#  b'-register"><a href="/register">Register</a></li>\r\n        <li><a href="/'
#  b'login">Login</a></li>\r\n                \r\n      </ul>\r\n      </div>\r\n'
#  b'    </div>\r\n\r\n</div><div class="body container">\r\n\r\n<div id="obsolet'
#  b'e" style="display:none">Your browser is <em>obsolete.</em> Please upgrade to'
#  b' a modern browser to properly experience BidBud and any other website. BidBu'
#  b'd works best with <a href="https://www.google.com/chrome/">Chrome</a> or <a '
#  b'href="https://www.firefox.com">Firefox</a></div>   \r\n<script async src="'
#  b'https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub'
#  b'-8211246382079842"\r\n    crossorigin="anonymous"></script>\r\n<ins class="a'
#  b'dsbygoogle"\r\n     style="display:block"\r\n     data-ad-client="ca-pub-821'
#  b'1246382079842"\r\n     data-ad-slot="2661431512"\r\n     data-ad-format="aut'
#  b'o"\r\n     data-full-width-responsive="true"></ins>\r\n<div id="featured" st'
#  b'yle="display: none"></div>\r\n<script>\r\n(adsbygoogle = window.adsbygoogle '
#  b'|| []).push({})\r\n</script>\r\n<script>\r\n    (function(h,o,t,j,a,r){\r\n '
#  b'       h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};\r\n    '
#  b'    h._hjSettings={hjid:1501141,hjsv:6};\r\n        a=o.getElementsByTagNa'
#  b"me('head')[0];\r\n        r=o.createElement('script');r.async=1;\r\n        "
#  b'r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;\r\n        a.appendChild('
#  b"r);\r\n    })(window,document,'https://static.hotjar.com/c/hotjar-','.js?s"
#  b'v=\');\r\n</script>\r\n\r\n\r\n        <div id="view-header" class="page-'
#  b'header">\r\n        <a href="/browse">Home</a> &gt; <a href="/search?categ'
#  b'ory=0002" rel="nofollow">Computers</a> &gt; <a href="/search?category=0356" '
#  b'rel="nofollow">Laptops</a> &gt; <a href="/search?category=0032" rel="nofollo'
#  b'w">Laptops</a> &gt; <a href="/search?category=2273" rel="nofollow">Apple</a>'
#  b'<span class="pull-right">Listing # 4754794981</span><h2>Apple Macbook Pro 20'
#  b'17 15.4&quot; Touchbar 16GB Mem / 512GB Storeage</h2>        <div class="row'
#  b'"><div class="col-sm-7 col-lg-6"><div id="item_info" class="panel panel-defa'
#  b'ult panel-body">\r\n        Listed on 10 Jun 2024. Closes <span id="end_da'
#  b'te">Mon 17 Jun, 9:09pm</span> &mdash; <span class="countdown">5 days</span><'
#  b'br><b>Start price <span id="current_bid">$1,000</span></b> <span id="reserve'
#  b'_icon"><small>reserve not met</small></span> <b>Buy now: $1,250.00</b> <b cl'
#  b'ass="bid_message"></b><br>1 person added this to their watchlist</div>\r\n'
#  b'        </div>\r\n        <div class="col-sm-5 col-lg-6">\r\n           '
#  b' \r\n            <div style="margin-left: 5px; margin-bottom:5px" class="b'
#  b'tn-group pull-right hidden-print" title="Click for more item specific action'
#  b's">\r\n              <button type="button" class="btn btn-default dropdown'
#  b'-toggle" data-toggle="dropdown">\r\n                Actions <span class="c'
#  b'aret"></span>\r\n              </button>\r\n              <ul class="dropdow'
#  b'n-menu" role="menu">\r\n                                <li><a target="_bl'
#  b'ank" rel="noopener" href="https://www.trademe.co.nz/4754794981" title="View '
#  b'this listing on TradeMe">View on TradeMe</a></li>\r\n\r\n              </ul>'
#  b'\r\n            </div>\r\n                        <button id="share_button" '
#  b'style="display:none" class="btn btn-default pull-right" type="button"><span '
#  b'class="glyphicon glyphicon-share"></span> Share</button>\r\n            <d'
#  b'iv id="calendar_modal" tabindex="-1" class="modal" role="dialog"></div>\r'
#  b'\n            <div id="share_modal" tabindex="-1" class="modal" role="dia'
#  b'log"></div>\r\n            <div id="note_modal" tabindex="-1" class="modal'
#  b'" role="dialog"></div>\r\n        \r\n        \r\n        </div>\r\n        '
#  b'\r\n        </div></div>\r\n  \r\n        <div class="row"><div class="col'
#  b'-sm-4" id="description">            <table id="listingattributes">\r\n    '
#  b'                    <tr><th>\r\n            Memory:</th><td>16 to 31 GB</t'
#  b'd></tr>\r\n                        <tr><th>\r\n            Screen Size:</th>'
#  b'<td>15"</td></tr>\r\n                        <tr><th>\r\n            Hard Dr'
#  b'ive Size:</th><td>500 to 999 GB</td></tr>\r\n                        </tab'
#  b'le>\r\n            <p>MacBook Pro 15 2017 - Core i7 2.9GHz 16GB RAM 512GB '
#  b'SSD <br>\nSpace Grey<br>\nOne owner. Ex Agency. Very Good Condition. Very '
#  b'few marks or scratched - always kept in 2 cases when travelling a soft case '
#  b'&amp; a study 2nd case. </p>\n\n<p>Screen size 15.4 inch Display<br>\nProce'
#  b'ssor: Core i7 2.9Ghz -16GB Ram<br>\nGraphics: 4GB<br>\nStoreage: 512GB har'
#  b'd drive<br>\nTouch bar </p>\n\n<p>Come with charger</p>        \r\n      '
#  b'  <div class="panel panel-default">\r\n          <div class="panel-heading'
#  b'">Seller information</div>\r\n          <div class="panel-body">\r\n        '
#  b'    <a href="https://www.bidbud.co.nz/search?member=561744" title="View memb'
#  b'er\'s listings"><b>jamarra</b></a>&nbsp;(<a href="https://www.bidbud.co.n'
#  b'z/members/feedback/561744" title="View member\'s feedback">30</a>&nbsp;<a'
#  b' href="https://www.bidbud.co.nz/members/feedback/561744" title="View mem'
#  b'ber\'s feedback"><span class="sprite sprite-star10">&nbsp;</span></a>)&nb'
#  b'sp;<img src="https://www.bidbud.co.nz/images/icon_av.gif" title="Address ver'
#  b'ified"><br>Member for 20 years<br>100% positive <a href="https://www.bidbud.'
#  b'co.nz/members/feedback/561744">feedback</a><br>Located in Tauranga, Bay of P'
#  b'lenty<br><b>Payment methods : </b>Ping, Cash, NZ Bank Deposit          \r'
#  b'\n                    \r\n          </div>\r\n        </div>\r\n           '
#  b'     </div><div class="col-sm-8 main-image">\r\n        <span class="sprit'
#  b'e sprite-rotate_cw rotate tooltips hidden-print" data-degrees="90" title="Ro'
#  b'tate image clockwise"></span><span class="sprite sprite-rotate_ccw rotate to'
#  b'oltips hidden-print" data-degrees="-90" title="Rotate image counterclockwise'
#  b'"></span>\r\n        \r\n        <div id="photodiv" class="royalSlider rsDef'
#  b'aultInv">\r\n                                              <img class="rsI'
#  b'mg" data-rsBigImg="https://trademe.tmcdn.co.nz/photoserver/plus/2123381177.j'
#  b'pg" src="https://trademe.tmcdn.co.nz/photoserver/full/2123381177.jpg" data-r'
#  b'sTmb="https://trademe.tmcdn.co.nz/photoserver/thumb/2123381177.jpg">\r\n  '
#  b'              \r\n                        </div>\r\n            \r\n      '
#  b'  </div>\r\n        </div>\r\n        \r\n                \r\n         <form'
#  b' action="https://www.bidbud.co.nz/item/process" id="bid_form" class="form-ho'
#  b'rizontal" style="margin-top: 10px" method="post" accept-charset="utf-8"><div'
#  b' style="display:none">\n<input type="hidden" name="auction_id" value="475'
#  b'4794981">\n<input type="hidden" name="title" value="Apple Macbook Pro 201'
#  b'7 15.4&quot; Touchbar 16GB Mem / 512GB Storeage">\n<input type="hidden" n'
#  b'ame="end_time" value="1718615375">\n<input type="hidden" name="questions"'
#  b' value="0">\n<input type="hidden" name="required_bid" value="500.00">\n<in'
#  b'put type="hidden" name="buy_now_price" value="1250">\n<input type="hidden'
#  b'" name="csrftok" value="e86778684560ad4e86d7bb0d273736e7">\n</div> \r\n    '
#  b'    <fieldset>\r\n                <div class="form-group">\r\n            <l'
#  b'abel for="amount" class="col-sm-3 col-md-2 control-label">Maximum amount</la'
#  b'bel>\r\n             <div class="col-sm-3 col-md-2">\r\n              <div c'
#  b'lass="input-group">\r\n                <span class="input-group-addon">$</'
#  b'span><input type="number" step="0.01" size="8" class="form-control" name="am'
#  b'ount" id="amount" data-bid="" \r\n                 value="">             <'
#  b'/div>\r\n             </div>\r\n             <label class="control-label pad'
#  b'-children-left">\r\n              <span class="bid_message"></span> <span '
#  b'class="minimum_bid_amount" data-minimum="500.00">Minimum bid: $500.00&nbsp;<'
#  b'a class="js-faq" title="Why can I bid less than reserve?" href="/faq#minimum'
#  b'_bid"><span class="glyphicon glyphicon-question-sign"></span></a></span>    '
#  b'          </label>\r\n              \r\n          </div>\r\n              '
#  b'             <div class="form-group">\r\n            <label class="col-sm-'
#  b'3 col-md-2 control-label">Shipping option</label>\r\n            <div clas'
#  b's="col-sm-9 col-md-10">\r\n                    <div class="radio">\r\n      '
#  b'  <label><input type="radio" name="shipping_option" value="1" checked="check'
#  b'ed" id="so1" required>                I will arrange shipping with the selle'
#  b'r\r\n                </label></div>\r\n                        <div class="r'
#  b'adio">\r\n        <label><input type="radio" name="shipping_option" value='
#  b'"2" id="so2" required>                I intend to pick up</label></div>\r'
#  b'\n                            </div>\r\n          </div>\r\n             '
#  b'                 <div class="form-group">\r\n            <label class="con'
#  b'trol-label col-sm-3 col-md-2">Delivery address</label>\r\n            <div'
#  b' class="col-sm-8 col-md-6">\r\n             <div class="checkbox">\r\n      '
#  b'       <label class="tooltips" data-placement="top" title="Send your deliver'
#  b'y address automatically if you win">\r\n             <input type="checkbox'
#  b'" id="enable_delivery_address" disabled>Send automatically\r\n            '
#  b' </label>\r\n             </div>\r\n\r\n              <select class="form-'
#  b'control" name="delivery_address" id="delivery_address" style="display:none">'
#  b'\r\n                \r\n              </select>\r\n             </div>\r\n  '
#  b'        </div>\r\n                              \r\n                    <div'
#  b' class="form-group">\r\n            <label class="control-label col-sm-3 c'
#  b'ol-md-2">Group</label>\r\n            <div class="col-sm-9">\r\n            '
#  b'  <select class="form-control medium has-help" name="group">\r\n          '
#  b'      <option></option>\r\n                            </select>\r\n        '
#  b'      <a class="js-faq" href="/faq#groups"><span class="glyphicon glyphicon-'
#  b'question-sign"></span></a>\r\n             </div>\r\n          </div>\r\n\r'
#  b'\n          <div class="form-group">\r\n            <label class="control-l'
#  b'abel col-sm-3 col-md-2" title="See FAQ for details">Bidding strategy</label>'
#  b'\r\n            <div class="col-sm-9 col-md-10">\r\n            <select name'
#  b'="strategy" class="form-control medium has-help">\n<option value="0" sele'
#  b'cted="selected">Fast</option>\n<option value="1">Slow</option>\n<option va'
#  b'lue="3">Adaptive</option>\n<option value="2">Blocking</option>\n</select> '
#  b'           \r\n            <a class="js-faq" data-id="bid_strategy"><span '
#  b'class="glyphicon glyphicon-question-sign"></span></a>\r\n             <div'
#  b' class="checkbox">\r\n             <label class="tooltips" data-placement='
#  b'"top" title="Send an email if you\'re outbid or new questions/comments ar'
#  b'e added. You\'ll always be sent an email if you win."><input type="checkb'
#  b'ox" name="email_if_outbid" value="1" checked="checked" >Email me if I\'m '
#  b'outbid or questions are added</label>\r\n             </div>\r\n            '
#  b'              \r\n             \r\n             <div class="checkbox">\r\n'
#  b'             <label class="tooltips" data-placement="top" title="Use Buy now'
#  b" or accept FPO if the seller adds one that's less than or equal to your bid."
#  b'"><input type="checkbox" name="use_buynow" value="1" checked="checked"  id="'
#  b'use_buy_now">Use Buy Now or Fixed Price Offer if it becomes available</label'
#  b'> <a class="js-faq" data-id="use_buy_now"><span class="glyphicon glyphicon-q'
#  b'uestion-sign"></span></a>\r\n             </div>\r\n             \r\n     '
#  b'        <div class="checkbox">\r\n             <label class="tooltips" dat'
#  b'a-placement="top" title="Click ? for further details"><input type="checkbox"'
#  b' name="round_bid_up" value="1"  id="round_bid_up">Round bid up if necessary<'
#  b'/label> <a class="js-faq" data-id="round_bid_up"><span class="glyphicon glyp'
#  b'hicon-question-sign"></span></a>\r\n             </div>\r\n             '
#  b' \r\n             <div class="checkbox">\r\n             <label class="toolt'
#  b'ips" data-placement="top" title="Only bid if reserve is met. If not, hopeful'
#  b'ly the seller will offer a FPO at a lower price.">\r\n             <input '
#  b'type="checkbox" name="outbid_only" value="1"  id="outbid_only">             '
#  b'Only bid if reserve is met\r\n             </label> <a class="js-faq" data'
#  b'-id="outbid_only"><span class="glyphicon glyphicon-question-sign"></span></a'
#  b'>\r\n             </div>\r\n                          <div class="checkbox">'
#  b'\r\n             <label class="tooltips" data-placement="top" title="If yo'
#  b'u lose the auction but the item is relisted, add it to your watchlist and sc'
#  b'hedule the same bid."><input type="checkbox" name="follow_relist" value="1" '
#  b' id="follow_relist">Bid again if item is relisted</label> <a class="js-faq" '
#  b'data-id="follow_relist"><span class="glyphicon glyphicon-question-sign"></sp'
#  b'an></a>\r\n             </div>\r\n             \r\n             <div class'
#  b'="checkbox">\r\n             <label class="tooltips" data-placement="top" '
#  b'title="Bid before the closing 2 minutes if bidding reaches 1 bid below your '
#  b'maximum"><input type="checkbox" name="allow_early_bid" value="1" >Bid early '
#  b'if single bid left</label> <a class="js-faq" data-id="bid_early"><span class'
#  b'="glyphicon glyphicon-question-sign"></span></a>\r\n             </div'
#  b'>\r\n\r\n             </div>\r\n             \r\n          </div>\r\n     '
#  b'               \r\n          <div id="item-buttons" class="col-sm-offset-3'
#  b' col-md-offset-2">\r\n                                                    '
#  b'<button class="btn btn-primary tooltips ajax-button endis" data-cancel-text='
#  b'"Cancel bid" data-set-text="Update bid" type="submit" title="Schedule your b'
#  b'id. BidBud will start bidding just before the auction ends, up to the maximu'
#  b'm specified above." id="schedule_bid"  name="schedule_bid" value="1" data-pl'
#  b'acement="bottom"><span class="glyphicon glyphicon-time"></span> Schedule bid'
#  b'</button>\r\n                              \r\n                       \t\t'
#  b'   \r\n\t\t         \r\n\t\t                                <!-- <button cla'
#  b'ss="btn btn-default tooltips ajax-button js-hide" type="submit" title="Offer'
#  b' the amount you enter in the maximum amount field to the seller" data-placem'
#  b'ent="bottom" name="offer" value="1">Make offer</button> -->\r\n           '
#  b'     <button class="btn btn-default tooltips ajax-button js-hide" type="subm'
#  b'it" data-cancel-text="Stop monitoring" title="When auction finishes, send an'
#  b" email with details on how much it sold for. You'll also be notified if any "
#  b'questions or comments are added." data-placement="bottom" name="monitor_clos'
#  b'ing_price" value="1"><span class="glyphicon glyphicon-eye-open"></span> Moni'
#  b'tor closing price</button>\r\n                                            '
#  b'                 <button class="btn btn-default" type="button" data-toggle="'
#  b'modal" href="#buy_now"><span class="glyphicon glyphicon-shopping-cart"></spa'
#  b'n> Buy now for $1,250.00</button>\r\n                        <div class="m'
#  b'odal" tabindex="-1" id="buy_now">\r\n            <div class="modal-dialog"'
#  b'>\r\n            <div class="modal-content">\r\n            <div class="moda'
#  b'l-header">\r\n            <button type="button" class="close" data-dismiss'
#  b'="modal">&times;</button>\r\n                        <h4 class="modal-titl'
#  b'e">Please log in</h4>\r\n                    </div>\r\n        <div class="m'
#  b'odal-body">\r\n                        <p>You need to log in to your Trade'
#  b' Me account to continue.</p>\r\n            <p>Simply log in, click "allow'
#  b'", and you\'ll be returned here to complete your purchase.</p>\r\n         '
#  b'           </div>\r\n        <div class="modal-footer">\r\n                 '
#  b'  <a class="btn btn-primary" href="/trademe/login">Login</a>\r\n          '
#  b'         <button class="btn btn-default" type="button" data-dismiss="modal">'
#  b'Cancel</button>\r\n        </div>\r\n        </div>\r\n        </div>\r\n   '
#  b' </div>\r\n                      </div>\r\n          <div id="alerts" class='
#  b'"col-sm-offset-3 col-md-offset-2 fade in"></div>\r\n        </fieldset>\r\n '
#  b'       </form>\r\n                \r\n    <div id="bid_div" class="centered '
#  b'hidden-print" style="max-width: 570px; display:none">\r\n    \r\n    <h3>Bid'
#  b' history</h3>\r\n    \r\n    <div class="countdown"></div>\r\n    <div id='
#  b'"current_autobid">\r\n    \r\n        </div>\r\n    <div id="bid_count_hol'
#  b'der">\r\n    <span id="bid_count">0</span> <span id="bid_text">bid</span>\r'
#  b'\n    <span id="extended_time"></span>\r\n    </div>\r\n    <table class='
#  b'"table">\r\n    \r\n    <thead>\r\n    \r\n    <tr>\r\n        <th>Amount<'
#  b'/th>\r\n        <th>Date and Time</th>\r\n        <th>Bidder</th>\r\n    <'
#  b'/tr>\r\n    </thead>\r\n  \r\n    <tbody id="bids">\r\n              \r\n '
#  b'   </tbody></table>\r\n    </div>\r\n        \r\n                 <div id='
#  b'"auction_questions" class="centered" >\r\n             <h3 class="hidden-p'
#  b'rint">Questions and answers</h3>\r\n                              <div cla'
#  b'ss="question">\r\n                     <a class="btn btn-default" style="m'
#  b'argin-bottom: 6px;" data-toggle="modal" href="#ask_question" class="hidden-p'
#  b'rint">Ask the seller a question</a>\r\n                     <form action="'
#  b'https://www.bidbud.co.nz/auction/ask_question" method="post" accept-charset='
#  b'"utf-8"><div style="display:none">\n<input type="hidden" name="auction_id'
#  b'" value="4754794981">\n<input type="hidden" name="csrftok" value="e867786'
#  b'84560ad4e86d7bb0d273736e7">\n</div>                     <div tabindex="-1'
#  b'" class="modal fade" id="ask_question">\r\n                     <div class'
#  b'="modal-dialog">\r\n                     <div class="modal-content">\r\n    '
#  b'                    <div class="modal-header">\r\n                        '
#  b'    <button type="button" class="close" data-dismiss="modal">&times;</button'
#  b'>\r\n                            <h4 class="modal-title">Ask a question</h'
#  b'4>\r\n                        </div>\r\n                        <div class="'
#  b'modal-body">\r\n                        <button class="btn btn-default tex'
#  b't_shortcut" type="button" data-text="Hi, what area in Tauranga is pickup? Th'
#  b'anks.">Ask pickup area</button>\r\n                        <button class="'
#  b'btn btn-default text_shortcut" type="button" data-text="Hi, would you take $'
#  b'| Buy Now? Thanks.">Ask for buy now</button>\r\n                        <b'
#  b'utton class="btn btn-default text_shortcut" type="button" data-text="Hi, how'
#  b' much for postage to |? Thanks.">Ask about postage</button>\r\n           '
#  b'             <textarea name="question" cols="80" rows="10" id="question" sty'
#  b'le="width:97%" autofocus></textarea>\r\n                        \r\n        '
#  b'                                        </div>\r\n                        '
#  b'<div class="modal-footer">\r\n                            <span id="questi'
#  b'on-error" class="warning"></span>\r\n                            <button c'
#  b'lass="btn btn-primary" type="submit" name="ask_question" id="question_button'
#  b'">Ask</button>\r\n                            <button class="btn btn-defau'
#  b'lt" type="button" data-dismiss="modal">Cancel</button>\r\n                '
#  b'        </div>\r\n                     </div>\r\n                     </div>'
#  b'\r\n                     </div>\r\n                     </form>\r\n       '
#  b'          </div>\r\n                 </div>                <div class="hid'
#  b'den-print" style="text-align: center">\r\n                <a href="/search'
#  b'?search_type=related&id=4754794981">More things you might like</a><br>\r\n'
#  b'                <small>View count: <span id="view_count">41 (viewed on avera'
#  b'ge every 57 minutes )</span>\r\n        <br>\r\n        Listing length: 7 da'
#  b'ys        </small>\r\n        </div>\r\n        \r\n<script type="applicat'
#  b'ion/ld+json">\r\n{\r\n\t"@context": "https://schema.org/",\r\n\t"@type": "Pr'
#  b'oduct",\r\n\t"name": "Apple Macbook Pro 2017 15.4\\" Touchbar 16GB Mem \\'
#  b'/ 512GB Storeage",\r\n\t"description": "MacBook Pro 15 2017 - Core i7 2.9GH'
#  b'z 16GB RAM 512GB SSD. Space Grey. One owner. Ex Agency. Very Good Condition.'
#  b'",\r\n    "image": "https:\\/\\/trademe.tmcdn.co.nz\\/photoserver\\/tq\\/21'
#  b'23381177.jpg",\r\n    "url": "https://www.bidbud.co.nz/4754794981",\r\n    "'
#  b'category": "Apple",\r\n\t"offers": [\r\n\t\t{\r\n\t\t\t"@type": "Offer",'
#  b'\r\n\t\t\t"priceCurrency": "NZD",\r\n\t\t\t"price": 1000,\r\n\t\t\t"itemCon'
#  b'dition": "https://schema.org/UsedCondition",\r\n\t\t\t"availability": "ht'
#  b'tps://schema.org/InStock",\r\n            "url": "https://www.bidbud.co.nz'
#  b'/4754794981"\r\n\t\t}\r\n\t]\r\n}\r\n</script>    </div>    \t\r\n    <scr'
#  b'ipt src="/assets/js/jquery-3.5.1.min.js"></script>\r\n  <script src="/asse'
#  b'ts/js/jquery-migrate-3.3.2.min.js"></script>\r\n  <script src="https://www'
#  b'.bidbud.co.nz/bonfire/themes/bootstrap3/js/bootstrap.min.js?v=223" type="tex'
#  b't/javascript" ></script>\n<script src="https://www.bidbud.co.nz/assets/js'
#  b'/toolbox.js?v=223" type="text/javascript" ></script>\n<script src="https:'
#  b'//www.bidbud.co.nz/assets/js/jquery.timeago.js?v=223" type="text/javascript"'
#  b' ></script>\n<script src="https://www.bidbud.co.nz/assets/js/jquery.royal'
#  b'slider.custom.min.js?v=223" type="text/javascript" ></script>\n<script sr'
#  b'c="https://www.bidbud.co.nz/assets/js/bootbox.min.js?v=223" type="text/javas'
#  b'cript" ></script>\n<script src="https://www.bidbud.co.nz/assets/js/jquery'
#  b'rotate.js?v=223" type="text/javascript" ></script>\n<script type="text/ja'
#  b'vascript">\n$(document).ready(function(){setup_view_listing();$("time.tim'
#  b'eago").timeago();\nif (/\\b(MS)?IE |\\bTrident\\/7/.test(navigator.userAgent'
#  b')) {$("#obsolete").show()}$(".tooltips").tooltip({trigger : "hover", delay: '
#  b'{ show: 1000, hide: 100 }});$(".dropdown-toggle").dropdown();if ($(".adsbygo'
#  b'ogle").css("display")=="none" || !window.ihaveads) {$(".adsbygoogle").css("d'
#  b'isplay","none");$("#featured").show().load( "/featured" );}$.ajaxSetup({cach'
#  b'e: false});$.ajaxPrefilter(function(options){if (options.type.toLowerCase() '
#  b'=== "post" && (!options.data || options.data.indexOf("csrftok")===-1) ) {opt'
#  b'ions.data=options.data||"";options.data+=(options.data?"&":"")+"csrftok=e867'
#  b'78684560ad4e86d7bb0d273736e7"}});\n});\n</script>\n  </body>\r\n</html>\r\n')

# %%
dict_keys = ['ListingId', \
             'Title', \
             'Category', \
             'StartPrice', \
             'BuyNowPrice', \
             'StartDate', \
             'EndDate', \
             'IsFeatured', \
             'BiddersAndWatchers', \
             'MaxMidAmount', \
             'IsNew', \
             'Region', \
             'Suburb', \
             'BidCount', \
             'ViewCount', \
             'IsReserveMet', \
             'HasReserve', \
             'HasBuyNow', \
             'ReserveState', \
             'RelistedItemId', \
             'Subtitle', \
             'IsBuyNowOnly', \
             'TotalReviewCount', \
             'UnansweredQuestionCount', \
            ]

listing_dicts = [dict.fromkeys(dict_keys) for i in range(len(ads_all) + 1)]

# %%
# Out:
# 1079
